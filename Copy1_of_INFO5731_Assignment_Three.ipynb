# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
import nltk
nltk.download('punkt')
with open("E:\Apparado\INFO5731_Assign2\Joker_reviews.csv", "r", encoding='utf-8') as file:
  data = file.read()

import pandas 
from textblob import TextBlob
tgrams = textblob(data).ngrams(4)
ngramsdata=dict()
for gram in tgrams:
  gramss=tuple(gram)
  ngramdata[gram]= ngramdata.get(gram,0)+1

df= pandas.DataFrame.from_dict(ngramsdata, orient = 'index', columns=['tri---grams frqy'])
df['trigrams frqy']= [val for val in ngramsdata.values()]
df
# Out:
#                                                tri---grams frqy  trigrams frqy
# (review_title, review_content, review_rating)                 1              1
# (review_content, review_rating, 0)                            1              1
# (review_rating, 0, As)                                        1              1
# (0, As, a)                                                    1              1
# (As, a, viewer)                                               1              1
# ...                                                         ...            ...
# (9/10, for, a)                                                1              1
# (for, a, DC)                                                  1              1
# (DC, movie, after)                                            1              1
# (movie, after, TDK)                                           1              1
# (after, TDK, 9/10)                                            1              1
#
# ...

# %%
import pandas
proprgramsdata= textblob(data)
bgrams=textblob(data).ngrams(4)
ngramsdata={}
for gram in bgrams:
  gram=tuple(gram)
  ngramdata[gram]=ngramdata.get(gram,0)+1
  
bgrm_probablity = {}
for key, val in ngramsdata.items():
    bgrm_probablity[key]=val/proprgramsdata.words.count(key[0])

df = pandas.DataFrame.from_dict(bgrm_probablity, orient = 'index', columns=['probability'])
df['frqy'] = [val for val in ngramsdata.values()]
df
# Out:
#                                  probability  frqy
# (review_title, review_content)      1.000000     1
# (review_content, review_rating)     1.000000     1
# (review_rating, 0)                  1.000000     1
# (0, As)                             0.333333     1
# (As, a)                             0.023438     3
# ...                                      ...   ...
# (my, second)                        0.027027     1
# (second, 9/10)                      0.142857     1
# (9/10, for)                         0.100000     1
# (after, TDK)                        0.043478     1
# (TDK, 9/10)                         1.000000     1
#
# [12126 rows x 2 columns]

# %%
import pandas
import nltk
nltk.download('brown')

proprgramsdata=TextBlob(data)

ngramsdata1={}
for np in proprgramsdata.noun_phrases:
  ngramsdata1[np]=ngramsdata1.get(np,0)+1
new_nphrases = [val for val in ngramsdata1.values()]
num_refreq_max = max([val for val in ngramsdata1.values()])
num_prob=[]
for line in data.splitlines():
  proprgramsdata=TextBlob(line)
  new_nphrases = proprgramsdata.noun_phrases
  ngramsdata1={}
  for np in nphrases:
    ngramsdata1[np]= ngramsdata1.get(np,0)+1
  for key, val in ngramsdata1.items():
    ngramsdata1[key] = val/max_refreq
  num_prob.append(ngramsdata1)
doc_index = [n for n in range (1, len(num_prob)+1)]
df = pandas.DataFrame (num_prob, index=doc_num)
df.fillna(0, inplace=True)
df
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
#          tiff  masterpiece  ...       p.s       tdk
# 1    0.000000     0.000000  ...  0.000000  0.000000
# 2    0.005952     0.005952  ...  0.000000  0.000000
# 3    0.000000     0.000000  ...  0.000000  0.000000
# 4    0.000000     0.000000  ...  0.000000  0.000000
# 5    0.000000     0.000000  ...  0.000000  0.000000
# ..        ...          ...  ...       ...       ...
# 169  0.000000     0.000000  ...  0.000000  0.000000
# 170  0.000000     0.000000  ...  0.000000  0.000000
# 171  0.000000     0.000000  ...  0.000000  0.000000
# 172  0.000000     0.000000  ...  0.000000  0.000000
# 173  0.000000     0.000000  ...  0.005952  0.005952
#
# [173 rows x 1135 columns]

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (40 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
# Write your code here
import pandas
from sklearn.feature_extraction.text import TfidfVectorizer
docs_1=[docs_1 for doc_1 in data.splitlines()]
data_docs = {v: i for value, i in enumerate(data.splitlines(),1)}
details= tf_idf.get_details()
data_docs_details = [e for e in data_docs]
df= pandas.DataFrame(tf_idf2.T.todense(), index= details, columns=data_docs_details)
df
# Out:
#        1    2         3         4    ...       170       171  172       173
# 10     0.0  1.0  0.513685  0.513685  ...  0.513685  0.668172  0.0  0.937506
# movie  0.0  0.0  0.857979  0.857979  ...  0.857979  0.744007  1.0  0.347969
#
# [2 rows x 173 columns]

# %%
from nltk.corpus import stopwords
import nltk
import re
from nltk.stem import PorterStemmer
nltk.download('stopwords')
nltk.download('wordnet')
from textblob import Word
wording= stopwords.words('english')
lines = " ".join(a for a in lines.split() if a not in stop)
st=PorterStemmer()
lines2= " ".join([st.stem(word) for word in lines.split()])
print(lines2)
#with open ("E:\Apparado\INFO5731_Assign2\Joker_reviews.csv","a", encoding='utf-8') as file:
 # file.write(data)
  #file.write(query)
#with open ("E:\Apparado\INFO5731_Assign2\Joker_reviews.csv","r", encoding='utf-8') as file:
  #data_query = file.read()
data_docs = [data_docs for data_docs in data_lines2.splitlines()]
data_docs_details = {v: e for i, e in enumerate( data_details.splitlines(), 1)}
tfid = TfidfVectorizer(input=data_docs, max_num= 50, min_data=0.2, lowercase= True, analyzer='word', stop_words='english', ngram_range=(1,5))
tfid_2=tfid.fit_transform(data_details.values())
name_details= tfid.get_name_details()
index_num=[a for c in index_num]
df=pandas.DataFrame(tf_idf2.T.todense(), index=name_details, columns=index_details)
df
# Out:
#          1         2         3         4    ...  345       346       347       348
# 10       0.0  0.900922  0.481699  0.481699  ...  0.0  0.275364  0.402005  0.208917
# 2019     0.0  0.307821  0.246875  0.246875  ...  1.0  0.000000  0.137354  0.214144
# helpful  0.0  0.305917  0.245349  0.245349  ...  0.0  0.280508  0.136505  0.212820
# movie    0.0  0.000000  0.804253  0.804253  ...  0.0  0.919505  0.894926  0.930163
#
# [4 rows x 348 columns]

# %%
import pandas
from sklearn.metrics.pairwise import cosine_similarity

cosimdata_details=1
data_details_frqncy={}
cosimdata_details=cosine_similarity(tfid_2[100], tfid_2[freqency])
data_details_frqncy['doc'+str(freqency)] = cosimdata_details
freqency+=1
  print(cosimdata_detail)
sorted_cosimdata_details = sorted (cosimdata_details, key=cosimdata_details.get, reverse=True)

rankings = {rankings for rankings, key in enumerate(sorted (rankings, key=rankings.get, reverse=True),1)}
cosimdata_list = [data_details_frqncy[doc]for doc in sorted_cosimdata_detail]
rankingdata=pandas.DataFrame.from_dict (rankings, orient='index', columns= ['ranking'])
rankingdata ['cosine similarity'] = cosimdata_details
rankingdata.head(50)
# Out:
# {'doc1': array([[0.]]), 'doc2': array([[0.]]), 'doc3': array([[0.]]), 'doc4': array([[0.]]), 'doc5': array([[0.]]), 'doc6': array([[0.]]), 'doc7': array([[0.]]), 'doc8': array([[0.]]), 'doc9': array([[0.]]), 'doc10': array([[0.]]), 'doc11': array([[0.]]), 'doc12': array([[0.]]), 'doc13': array([[0.]]), 'doc14': array([[0.]]), 'doc15': array([[0.]]), 'doc16': array([[0.]]), 'doc17': array([[0.]]), 'doc18': array([[0.]]), 'doc19': array([[0.]]), 'doc20': array([[0.]]), 'doc21': array([[0.]]), 'doc22': array([[0.]]), 'doc23': array([[0.]]), 'doc24': array([[0.]]), 'doc25': array([[0.]]), 'doc26': array([[0.]]), 'doc27': array([[0.]]), 'doc28': array([[0.]]), 'doc29': array([[0.]]), 'doc30': array([[0.]]), 'doc31': array([[0.]]), 'doc32': array([[0.]]), 'doc33': array([[0.]]), 'doc34': array([[0.]]), 'doc35': array([[0.]]), 'doc36': array([[0.]]), 'doc37': array([[0.]]), 'doc38': array([[0.]]), 'doc39': array([[0.]]), 'doc40': array([[0.]]), 'doc41': array([[0.]]), 'doc42': array([[0.]])
# ...

# %% [markdown]
# # **Question 3: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
# The GitHub link of your final csv file

# Link: https://github.com/sa0753/sangeeta/blob/master/Copy_of_Assignment3_Q3.ipynb

# %%
https://github.com/sa0753/sangeeta/blob/master/Copy_of_Assignment3_Q3.ipynb
