# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source via web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (40 points). Write a python program to collect text data from **either of the following sources** and save the data into a **csv file**:
#
# (1) Collect all the customer reviews of the product [2019 Dell labtop](https://www.amazon.com/Dell-Inspiron-5000-5570-Laptop/dp/B07N49F51N/ref=sr_1_11?crid=1IJ7UWF2F4GHH&keywords=dell%2Bxps%2B15&qid=1580173569&sprefix=dell%2Caps%2C181&sr=8-11&th=1) on amazon.
#
# (2) Collect the top 100 User Reviews of the film [Joker](https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv) from IMDB.
#
# (3) Collect the abstracts of the top 100 research papers by using the query [natural language processing](https://citeseerx.ist.psu.edu/search?q=natural+language+processing&submit.x=0&submit.y=0&sort=rlv&t=doc) from CiteSeerX.
#
# (4) Collect the top 100 tweets by using hashtag ["#wuhancoronovirus"](https://twitter.com/hashtag/wuhancoronovirus) from Twitter.

# %%
#part 1
import bs4
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
import pandas as pd

url = 'https://www.imdb.com/title/tt7286456/reviews?sort=totalVotes&dir=desc&ratingFilter=0'
myurl = uReq(url)
page_html = myurl.read()
myurl.close()
page_soup = soup(page_html, "html.parser")
reviews = page_soup.findAll("div",{"class":"review-container"})
print (reviews)
# Out:
# [<div class="review-container">
# <div class="lister-item-content">
# <div class="ipl-ratings-bar">
# <span class="rating-other-user-rating">
# <svg class="ipl-icon ipl-star-icon " fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M0 0h24v24H0z" fill="none"></path>
# <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z"></path>
# <path d="M0 0h24v24H0z" fill="none"></path>
# </svg>
# <span>10</span><span class="point-scale">/10</span>
# </span>
# </div>
# <a class="title" href="/review/rw5112402/"> As a viewer that actually went to TIFF and witnessed this film and didn't want to believe the hype, it is an absolute MASTERPIECE and Phoenix is a certified legend.
# </a> <div class="display-name-date">
# <span class="display-name-link"><a href="/user/ur107586329/">JF500</a></span><span class="review-date">10 September 2019</span>
# </div>
# <div class="content">
# ...

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points). Write a python program to **clean the text data** you collected above and save the data in a new column in the csv file. The data cleaning steps include:
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the [stopwords list](https://gist.github.com/sebleier/554280).
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
#part2
import bs4
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
from selenium import webdriver
import pandas as pd
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
import spacy
import re
import string
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk import Tree
nltk.download('stopwords')
nltk.download('wordnet')

url = 'https://www.imdb.com/title/tt7286456/reviews?sort=totalVotes&dir=desc&ratingFilter=0'
myurl = uReq(url)
page_html = myurl.read()
myurl.close()
page_soup = soup(page_html, "html.parser")
reviews = page_soup.findAll("div",{"class":"review-container"})
#datacleaning
#lowerletter
small_letter = result.lower()
print(small_letter)
# cleaning
cleaning =  re.sub(r"[:?,!]", "", str(lower))

#stopword (this code is similar code from geekstogeeks)
stopwording = set(stopwords.words('english'))
filter_sentence = [i for i in txt if not i in stop_words]

#tokenize
token = RegexpTokenizer("[\w']+")
result_token = token.tokenize(str(numelim)) 

#stem
stemming = PorterStemmer()
for i in filter_sentence:
  print(i,":",stemming.stem(i))
  
#lemmati
lemmatiz = WordNetLemmatizer()
for i in filter_sentence:
  print(i, " : ", lemmatiz.lemmatize(i))
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# most of the time movies are anticipated like this they end up falling short, way short. joker is the first time i was more than happy with the hype. please ignore the complaints of "pernicious violence" as they are embarrassing to say the least. we haven't seen a comic movie this real before. if we ever "deserved" a better class of criminal - phillips and phoenix have delivered. this is dark, joker is dark and you will fall in love with the villain as you should. the bad guys are always more romantic anyway.
#
#                     2,371 out of 2,957 found this helpful.
#
#                             was this review helpful?  sign in to vote.
#
#
# permalink
#
#
#
#
# ,
#
#
#
#
#
#
#
#
# 10/10
#
#
#  just amazing. how does this movie exist.
#
# vallejodiego4 october 2019
#
#
# ...

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just saved above. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
#dependecy parsing( I am not sure how to do it)
import nltk
from nltk.data import find
from bllipparser import RerankingParser

tree_parsing = find('/review/rw5092831/?ref_=tt_urv').path
parsing = RerankingParser.from_unified_tree_parsing(tree_parsing)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-55-1f33adbba0cf> in <module>()
#       1 import nltk
#       2 from nltk.data import find
# ----> 3 from bllipparser import RerankingParser
#       4
#       5 tree_parsing = find('/review/rw5092831/?ref_=tt_urv').path
#
# ModuleNotFoundError: No module named 'bllipparser'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**

# %% [markdown]
# Dependency parsing is used to define any grammatical structure sentence by listing each word as a node adn tryto lonl to its dependents.
#
# Constituency parsing tree usese contex free grammar to display syntactic structure.

# %%
#Constituencyparsetree
cons_tree = pred.predict(sentence = "My name is Sangeeta")
print (cons_tree)
tree
# Out:
# {'class_probabilities': [[1.0, 1.54444391303743e-11, 7.919044431569646e-16, 7.477610246492752e-15, 7.644398762982768e-16, 1.829490199741976e-13, 5.982473766591792e-14, 3.4436758999945027e-12, 3.53278656328726e-11, 3.1707915373185847e-13, 2.429272493275204e-16, 1.3559819262711718e-14, 4.2498951580149935e-10, 3.821725413617836e-15, 4.3664551141464614e-11, 6.116840432605908e-13, 2.634558763097046e-15, 7.73546428734645e-13, 1.593753883206983e-13, 9.076498436850176e-15, 6.014706961654515e-13, 5.798598060047233e-11, 4.2047110238030427e-10, 6.180883441782997e-14, 8.053722754886375e-14, 1.3681696292393297e-13, 8.3607410274536e-14, 2.380337897275875e-12, 1.2169534958472294e-14, 5.324508737560019e-13, 1.8995417218337085e-12, 1.8369774017895635e-12, 6.670018704024727e-12, 9.502917522980978e-14, 4.573758364233294e-13, 9.253235330741738e-12, 2.26741585576673e-13, 5.879423467178291e-13, 4.3048184916912036e-13, 1.7605961176794804e-12, 1.953465384244013e-12, 2.013306920267341e-13, 1.7505898260942315
# ...
